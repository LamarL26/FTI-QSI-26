# %% [markdown]
# <a href="https://colab.research.google.com/github/LamarL26/FTI-QSI-26/blob/main/QSI's_PythonProgramming_Day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
# # **Python Programming: Part I**
# ---
#
#
# ### **Description**
# This notebook is designed to provide hands-on practice with Python basics to solidify the foundation upon which we will build our machine learning and data science skills in the upcoming program.
#
#
# <br>
#
# ### **Lab Structure**
# **Part 1**: [Getting Familiar with Google Colab](#p1)
#
# **Part 2**: [Print Statements](#p2)
#
# **Part 3**: [Creating Variables](#p3)
#
# **Part 4**: [Variables and Data Types](#p4)
#
# **Part 5**: [Arithmetic Operators](#p5)
#
# **Part 6**: [Booleans and Comparison Operators](#p6)
#
#
# **Part 7**: [Conditionals - `if`](#p7)
#
# **Part 8**: [Conditionals - `else`](#p8)
#
# **Part 9**: [Conditionals - `and` & `or`](#p9)
#
# **Part 10**: [Conditionals - `elif`](#p10)
#
# **Part 11**: [Independent Practice](#p11)
# <br>
#
# ### **Learning Objectives**
#  By the end of this lab, we will:
# * Recognize how information is outputted to the screen.
# * Recognize that variables are a way to store data.
# * Recognize the main data types and how to modify them with basic arithmetic operators.
#
#
# <br>
#
#
# ### **Resources**
# * [Python basics Cheat Sheet](https://docs.google.com/document/d/1P3mae56ecUhbi3zq5eCT9T7HamCGEcd3lqqdZvUZAvU/edit?usp=sharing)

# %% [markdown]
# <a name="p1"></a>
#
# ---
# ##**Part 1: Getting Familiar with Google Colab**
# ---

# %% [markdown]
# #### **Problem #1.1**
#
# **Together**, let's change the title of our notebook. Rename the notebook to "Python Pre-Training Session 1 Lab Notebook".

# %% [markdown]
# #### **Problem #1.2**
#
# **Together**, let's create a new text cell and type: "This is a text cell."

# %% [markdown]
# #### **Problem #1.3**
#
# **Together**, let's create a new code cell and type: "This is a code cell."

# %% [markdown]
# #### **Problem #1.4**
#
# **Together**, let's run the code cell below.

# %%
"Hello World!"
# Out:
# 'Hello World!'

# %% [markdown]
# #### **Problem #1.5**
#
# **Together**, let's run the code cell below.

# %%
print('This line of code will execute first.')

print('Then, the computer will run this line of code.')

print('After, this line of code will run.')
# Out:
# This line of code will execute first.
# Then, the computer will run this line of code.
# After, this line of code will run.

# %% [markdown]
# **Notice** how each line of code is displayed after one another. This because our computer runs the code **sequentially**. Whatever is written first in code will output first.

# %% [markdown]
# ---
#
# <center>
#
# ### **Back to Lab Slides**

# %% [markdown]
# <a name="p2"></a>
#
# ---
# ## **Part 2: Print Statements**
# ---

# %% [markdown]
# #### **Problem #2.1**
#
# **Together,** let's create a code cell and type: `print("Hello!")`.

# %% [markdown]
# #### **Problem #2.2**
#
#
# **Together,** let's create a code cell and type: `print("Today I learned about the basics of Python programming!")`.

# %% [markdown]
# ---
#
# ### **Try Problems #2.3-2.6 on your own.**

# %% [markdown]
# #### **Problem #2.3**
#
#
# **Independently,** print your favorite color.

# %% [markdown]
# #### **Problem #2.4**
#
#
# **Independently,** print a sentence that describes what state or country you are from.

# %% [markdown]
# #### **Problem #2.5**
#
# **Independently,** print the food you had for breakfast today.

# %% [markdown]
# #### **Problem #2.6**
#
# The ability to choose between single quotes and double quotes is useful when trying to print either of these characters. We can use one to print the other.
#
# **The code below is provided for you. Run it to print the statements**

# %%
print("My cat's name is Charlie.")

print('Charlie said "meow".')
# Out:
# My cat's name is Charlie.
# Charlie said "meow".

# %% [markdown]
# ---
#
# <center>
#
# ### **Back to Lab Slides**

# %% [markdown]
# #### **Problem #2.7**
#
# **Together,** let's create a code cell and print your favorite number.

# %% [markdown]
# #### **Problem #2.8**
#
#
# **Together,** let's create a code cell and print the sum of 33 and -11.

# %% [markdown]
# ---
#
# ### **Try Problems #2.9-2.12 on your own.**

# %% [markdown]
# #### **Problem #2.9**
#
#
# **Independently,** print the number of months in a year.

# %%
print("There are 12 months in a year")
# Out:
# There are 12 months in a year

# %% [markdown]
# #### **Problem #2.10**
#
#
#
# **Independently,** print the current year.

# %% [markdown]
# #### **Problem #2.11**
#
#
#
# **Independently,** print today's date in the following format: MMDDYYYY.

# %%
print(6,"/",13,"/",2026, sep = "")
# Out:
# 6/13/2026

# %% [markdown]
# #### **Problem #2.12**
#
#
#
# **Independently,** print the sum of your age plus the age of your best friend.

# %% [markdown]
# ---
#
# <center>
#
# ### **Back to Lab Slides**

# %% [markdown]
# <a name="p3"></a>
#
#
# ---
# ## **Part 3: Creating Variables**
# ---

# %% [markdown]
# ####**Problem #3.1**
#
# **Together,** let's create a variable called `ten` to store the number 10.

# %%
ten = 10
print(ten)
# Out:
# 10

# %% [markdown]
# #### **Problem 3.2**
#
# **Together,** let's create a variable called `introduction` to store the word "Hello".

# %%
introduction = "Hello"
print(introduction)
# Out:
# Hello

# %%
intro='Hello'
print(intro)
# Out:
# Hello

# %% [markdown]
# ---
#
# #### **Try Problems #3.3-3.4 on your own.**

# %% [markdown]
# #### **Problem 3.3**
#
# **Independently,** create a variable called `year` to store the number 2026.

# %%
year = "6/13/2026"
print(year)
# Out:
# 6/13/2026

# %% [markdown]
# #### **Problem 3.4**
#
# **Independently,** create a variable called `month` to store the word "June".

# %%
month = "June"
print(month)
# Out:
# June

# %% [markdown]
# ---
# <center>
#
# ###**Back to Lab Slides**

# %% [markdown]
# #### **Problem 3.5**
#
# **Together,** let's determine which variable names are valid or invalid.
#
# ```
# hello, #Invalid
# sampleVariable #Valid
# my_password #Valid
# variable name #Invalid
# True #Invalid
# ```

# %% [markdown]
# ---
#
# #### **Try Problem #3.6 on your own.**

# %% [markdown]
# #### **Problem 3.6**
#
# The variables in the code below are poorly named.
#
# **Independently,** rename the variables so that they are well named.

# %%
my_name = "Jane"
Straight = "https://the-cs.org"
two_two = 4
PLANT = "Orchid"
prime_number = 17

# %% [markdown]
# ---
#
# ###**Back to Lab Slides**

# %% [markdown]
# <a name="p4"></a>
#
# ---
# ## **Part 4: Variables & Data Types**
# ---

# %% [markdown]
# #### **Problem #4.1**
#
#
# **Together,** let's create a variable called `my_name` and assign it to your first name. Print this variable.

# %%
my_name = "Lamar"
print(my_name)
# Out:
# Lamar

# %% [markdown]
# #### **Problem #4.2**
#
# **Together,** let's create and name a variable with your favorite number as an integer. Print that variable.

# %%
fav_number = 33
print(fav_number)
# Out:
# 33

# %% [markdown]
# ---
# ### **Problem #4.3**
#
# **Together,** let's create and name a variable with your favorite number as a float. Print that variable.

# %%
fav_number = 33.0
print(fav_number)
# Out:
# 33.0

# %% [markdown]
# ---
#
# ### **Try Problems #4.4-4.6 on your own.**

# %% [markdown]
# #### **Problem #4.4**
#
#
#
# **Independently,** look through the given declarations. Which ones are incorrect?
#
# ```
# Var1 = 7
# VAR5 = 8
# 2var = 92
# first_last_name = "james gooding"
# Hello = 0.283
# variable24 = "my favorite food is"
# str = "string"
# ```

# %% [markdown]
# #### **Problem #4.5**
#
#
# **Independently,** create and a name a variable that stores a list of 3 fruits. Print that variable.

# %%
listexample = ["bananas","watermelon","mango"]
print(listexample)
# Out:
# ['bananas', 'watermelon', 'mango']

# %% [markdown]
# #### **Problem #4.6**
#
# **Independently,** create two variables to represent your height, one variable for feet called `feet` and one for inches called `inches`.

# %%
feet = 5
inches = 11
print(feet,inches)
# Out:
# 5 11

# %% [markdown]
# ---
# <center>
#
# ###**Back to Lab Slides**

# %% [markdown]
# #### **Problem #4.7**
#
# **Independently,** enter your first name, then enter your last name separately. Output your full name.

# %%
first_name = "Lamar"
last_name = "Logan"
full_name = "Lamar Logan"
print("Hi, my name is " + full_name + " and I would love to do Security Engineering. On the documentation, I would put " + first_name + " as my first name and " + last_name + " as my last name.")
# Out:
# Hi, my name is Lamar Logan and I would love to do Security Engineering. On the documentation, I would put Lamar as my first name and Logan as my last name.

# %% [markdown]
# <a name="p5"></a>
#
# ---
# ## **Part 5: Arithmetic Operators**
# ---

# %% [markdown]
# #### **Problem #5.1**
#
#
# **Together,** let's print the sum of 3 and 2. Take note of the output.

# %%
print(3+2)
# Out:
# 5

# %% [markdown]
# #### **Problem #5.2**
#
# **Together,** let's print the sum of 7.0 and 2.0. Take note of the output.

# %%
print(7.0+2.0)
# Out:
# 9.0

# %% [markdown]
# #### **Problem #5.3**
#
#
# **Together,** let's determine what 23 divided by 2 is. Print the answer. Take note of the output.

# %%
print(23/2)
# Out:
# 11.5

# %% [markdown]
# #### **Problem #5.4**
#
#
# **Together,** let's print the product of 24.0 and 25.4. Take note of the output.

# %%
print(24.0*25.4)
# Out:
# 609.5999999999999

# %% [markdown]
# #### **Problem #5.5**
#
#
# **Together,** let's create and name a variable `fav_number` with your favorite number as an integer. Multiply the variable by 3 and print the result.

# %%
fav_number = 17
result = 17*3
print(result)
# Out:
# 51

# %% [markdown]
# #### **Problem #5.6**
#
#
# **Together,** let's create and name two variables `fav_animal` with your favorite animal and `fav_color`. Print out a sentence using both of these.

# %%
fav_animal = "panda"
fav_color = "blue"
print("My favorite animal is a " + fav_animal + " and my favorite color is " + fav_color)
# Out:
# My favorite animal is a panda and my favorite color is blue

# %% [markdown]
# #### **Problem #5.7**
#
#
# **Together,** let's create and name a variable `age` that stores your age as an integer. Create and name another variable with your birthday as a string. Print out a sentence using both of these.

# %%
age = 22
birthday = "November 3st, 2026"

print("I am " + str(age) + " years old, and my birthday is on " + birthday)
# Out:
# I am 22 years old, and my birthday is on November 3st, 2026

# %% [markdown]
# ---
#
# ### **Try Problems #5.8-5.14 on your own.**

# %% [markdown]
# #### **Problem #5.8**
#
# **Independently,** by adding variables, determine how many fruits you have in total if you have 2 bananas and 5 apples.

# %%
bananas = 2
apples = 5

print(bananas + apples)
# Out:
# 7

# %% [markdown]
# #####**Solution**

# %%
bananas = 2
apples = 5
fruits = bananas + apples
print(fruits)
# Out:
# 7

# %% [markdown]
# #### **Problem #5.9**
#
#
# You got a 90 on your biology test, and then answered the extra credit question, which gave you an additional 4 points.
#
# **Independently,** calculate and print your final grade.

# %%
original_grade = 90
bonus = 4
test_score = original_grade + bonus
print(test_score)
# Out:
# 94

# %% [markdown]
# #####**Solution**

# %%
original_grade = 90
bonus = 4
final_grade = original_grade + bonus
print(final_grade)
# Out:
# 94

# %% [markdown]
# #### **Problem #5.10**
#
#
# The length and width of a rectangle are 5 and 8, respectively.
#
# **Independently,** calculate the area of a rectangle using these variables and print the result.

# %%
length = 5
width = 8
area = length*width
print(area)
# Out:
# 40

# %% [markdown]
# #####**Solution**

# %%
length = 5
width = 8
area = length * width
print(area)
# Out:
# 40

# %% [markdown]
# #### **Problem #5.11**
#
#
# **Independently,** create three variables `num1`, `num2`, and `num3` and assign them the values of 5, 24, and 67, respectively. Then calculate the average of these three numbers.

# %%
num1 = 5
num2 = 24
num3 = 67
average = (num1 + num2 + num3 / 3)
print(average)
# Out:
# 51.33333333333333

# %% [markdown]
# #### **Problem #5.12**
#
#
# **Independently,** create a variable storing someone's first name and another one for their last name. Concatenate them and print out a greeting using both variables.

# %%
first = "Lamar"
last = "Logan"
print("Hey, my name is " + first + " " + last + " and it is a pleasure to meet you!")
# Out:
# Hey, my name is Lamar Logan and it is a pleasure to meet you!

# %% [markdown]
# #### **Problem #5.13**
#
#
# **Independently,** create a variable storing an employee's first name. Create another one called `employee_id` which is an integer.
#
# This employee's username combines their first name and their id together. Create this username and print it out.

# %%
employee_name = "Michaela"
employee_id = 4890564
username = employee_name + str(employee_id)
print(username)
# Out:
# Michaela4890564

# %% [markdown]
# #####**Solution**

# %%
first_name = "Alice"
employee_id = 101

# Convert the integer ID to a string before concatenating
username = first_name + str(employee_id)

print("Generated Username:", username)

# %% [markdown]
# #### **Problem #5.14**
#
#
# **Independently,** write a program that takes a website name (like "google") and concatentates the prefix `www.` to the front and the suffix `.com` to the black to create a website address.

# %%
website = "TerpBridge"
front = "www."
end = ".com"
print(front + website + end)
# Out:
# www.TerpBridge.com

# %% [markdown]
# ---
# <center>
#
#
# ###**Back to Lab Slides**

# %% [markdown]
# <a name="p6"></a>
#
# ---
# ## **Part 6: Booleans and Comparison Operators**
#
# ---

# %% [markdown]
# ####**Problem #6.1**
#
# **Together,** let's determine which of these booleans are `True`, and which are `False`.
#
# ```
# 3 + 3 == 6 #True
# "hello" != "Hello" #True
# 4 <= 2 #False
# 5 > -1 #True
# 10 >= 10 #True
# "10" == 10 #False
# ```

# %%
"10" == 10
#The true or false statement is dependant on the last concatetation
# Out:
# False

# %% [markdown]
# ####**Problem #6.2**
#
# **Together,** create a variable called `true_boolean` and assign it to True. Next, create a variable called `false_boolean` and assign it to False.

# %%
true_boolean = True
false_boolean = False

# %% [markdown]
# ####**Problem #6.3**
#
# **Together,** write an expression that checks if `age` is greater than 18.

# %%
age = 20
age > 18
# Out:
# True

# %% [markdown]
# ---
#
# ###**Try Problems #6.3-6.5 on your own.**

# %% [markdown]
# #### **Problem #6.3**
#
# **Independently,** write an expression what will check if `test_score` is greater than or equal to 80.

# %%
test_score = 80
test_score >= 80
# Out:
# True

# %% [markdown]
# ####**Problem 6.4**
#
# You are given the variable `balance` which represents the amount of money in your bank account and `withdraw_amount` which represents the amount of money you are trying to withdraw.
#
# **Independently,** create a boolean variable called `can_withdraw` using boolean operators to determine whether or not you have enough money to complete the withdraw.

# %%
balance = 150
withdraw_amount = 200
can_withdraw = 150 >= 200
can_withdraw
# Out:
# False

# %% [markdown]
# ####**Problem #6.5**
#
# Given,
# ```
# x = 10
# y = 5
# ```
#
# **Independently,** predict which of these statements will return True, and which will return False.
#
# ```
# x - y == y #True
# y + y == x #True
# x == y #False
# x != y #True
# x > y #True
# x <= y #False
# ```

# %% [markdown]
# <a name="p7"></a>
#
# ---
# ## **Part 7: Conditionals - `if`**
#
# ---

# %% [markdown]
# #### **Problem #7.1**
#
# **Together,** let's create a variable called `temp`. If the temperature is below 40 °F, print a message stating that it is cold outside.

# %%
temp = 35
if temp < 40:
  print("It is frezzing outside!")
# Out:
# It is frezzing outside!

# %% [markdown]
# #### **Problem #7.2**
#
# **Together,** let's write some code that prints a New Year's message. Use an if statement to determine whether `year` is a leap year. If it is, then your message should also include this. Test your code on multiple different years.
#
# ```
# Happy New Year! Good luck in 2024!
# 2024 is a leap year.
# ```
#
# **Hint:** 2020 and 2024 are both leap years.

# %%
year = 2024

print("Happy New Year! Good luck in " + str(year) + "!")

if year % 4 == 0:
  print(year, "is a leap year.")
# Out:
# Happy New Year! Good luck in 2024!
# 2024 is a leap year.

# %% [markdown]
# #### **Problem #7.3**
#
# **Together,** let's create a variable called `my_num` and print the absolute value of `my_num`, in other words, if `my_num` is negative you need to make it positive before printing.

# %%
my_num = -5

if my_num < 0:
  my_num + my_num * -1

print("The number is", my_num)
# Out:
# The number is -5

# %% [markdown]
# ---
#
# ### **Try Problems #7.4-7.5 on your own.**

# %% [markdown]
# #### **Problem #7.4**
#
# Water only boils at or above 100 °C.
#
# **Independently,** create a variable, `water_temp`, which represents the temperature of the water, and print the statement "The water is boiling" only if the water is boiling.

# %%
water_temp = 105

if water_temp >= 100:
  print("The water is boiling.")
# Out:
# The water is boiling.

# %% [markdown]
# #### **Problem #7.5**
#
# **Independently,** write an `if` statement that prints "The number [num] is even" if `num` is even.

# %%
num = 4

if num % 2 == 0:
  print("The number", num, "is even.")
# Out:
# The number 4 is even.

# %% [markdown]
# ---
# <center>
#
# ###**Back to Lab Slides**

# %% [markdown]
# <a name="p8"></a>
#
# ---
# ## **Part 8: Conditionals - `else`**
#
# ---

# %% [markdown]
# #### **Problem #8.1**
#
# **Together,** let's build off of your solution from **Problem #7.1** and add an `else` statement.

# %%
temp = 32

if temp > 40:
  print("Go outside. Have fun!")
else:
  print("You better sit down inside!")
# Out:
# You better sit down inside!

# %% [markdown]
# #### **Problem #8.2**
#
# **Together,** let's build off of your solution from **Problem #7.2** and add an `else` statement that tells us when the `year` is not a leap year.

# %%
year = 2026

print("Happy New Year! Good luck in " + str(year) + "!")

if year % 4 ==0:
  print("Tt is a leap year.")
else:
  print("It is not a leap year.")
# Out:
# Happy New Year! Good luck in 2026!
# It is not a leap year.

# %% [markdown]
# ---
#
# ### **Try Problems #8.3-8.5 on your own.**

# %% [markdown]
# #### **Problem #8.3**
#
# **Independently,** build off of your solution from **Problem #7.4** and add an `else` statement.

# %%
water_temp = 95

if water_temp >= 100:
  print("The water is boiling.")
else:
  print("The water is no where near done. Make sure that you keep it on for a little longer.")
# Out:
# The water is no where near done. Make sure that you keep it on for a little longer.

# %% [markdown]
# #### **Problem #8.4**
#
# **Independently,** build off of your solution from **Problem #7.5** and modify it so that it prints whether `num` is even or odd.

# %%
num = 3

if num % 2 == 0:
  print("The number", num, "is even.")
else:
  print("The number", num, "is odd.")
# Out:
# The number 3 is odd.

# %% [markdown]
# #### **Problem #8.5**
#
# **Independently,** write a program that converts time (hours and minutes) from 24-hr to 12-hr format and displays it.
#
# For example:
# ```python
# hours = 14
# minutes = 23
# ```
# Should output:
# ```
# 14:23 --> 2:23 PM
# ```

# %%
hours = 14
minutes = 23

if hours <= 12:
  print(hours, ":", minutes," --> ",hours, ":", minutes, " AM", sep = "")
else:
  new_hours = hours-12
  print(hours, ":", minutes," --> ",new_hours, ":", minutes, " PM", sep = "")
# Out:
# 14:23 --> 2:23 PM

# %% [markdown]
# ---
# <center>
#
# ###**Back to Lab Slides**

# %% [markdown]
# <a name="p9"></a>
#
# ---
# ## **Part 9: Conditionals - `and` & `or`**
# ---

# %% [markdown]
# #### **Problem #9.1**
#
# A robot needs to sort through a shipment of assorted fruits and vegetables and discard any that are either bruised ***or*** moldy.
#
# **Together,** let's finish programming the robot to complete the given task.

# %%
bruised = False
moldy = True

if bruised == True or moldy == True:
  print('Discard this item.')
# Out:
# Discard this item.

# %% [markdown]
# #### **Problem #9.2**
#
# The same robot must now properly sort the remaining fruits and vegetables but is only able to identify the different produce based on their `shape` and `color`.
#
#
# | Produce     | Shape | Color  |
# | ----------- | ----- | ------ |
# | **apple**   | round | red    |
# | **banana**  | long  | yellow |
# | **carrot**  | long  | orange |
# | **lemon**   | round | yellow |
# | **orange**  | round | yellow |
#
#
# **Together,** let's finish programming the robot to identify the produce from the different combinations of characteristics.

# %%
shape = 'round'
color = 'green'

if shape == 'round' and color == 'red':
  print('Apple')

if shape == 'long' and color == 'yellow':
  print('Banana')

if shape == 'long' and color == 'orange':
  print('Carrot')

if shape == 'round' and color == 'yellow':
  print('Lemon')

if shape == 'round' and color == 'orange':
  print('Orange')

if shape == 'round' and color == 'green':
  print('watermelon')
# Out:
# watermelon

# %% [markdown]
# #### **Problem #9.3**
#
# **Together,** let's write a function such that if the `weather` is `raining` or the `temperature` is below 60 °F, it will ouptut "Better wear a jacket!". Otherwise, it will output "No jacket needed."

# %%
weather = "raining"
temperature = 50

if weather == "raining" or temperature < 60:
  print("Better wear a jacket!")
else:
  print("No jacket needed.")
# Out:
# Better wear a jacket!

# %% [markdown]
# ---
#
# ### **Try Problems #9.4-9.5 on your own.**

# %% [markdown]
# #### **Problem #9.4**
# **Independently,** write a function such that if `cloudy = False` and `raining = True`, it will print "There's a rainbow!". Otherwise, it will print "No rainbow."

# %%
cloudy = False
raining = False

if cloudy == False and raining == True:
  print("There's is a rainbow!")
else:
  print("No rainbow, sadly!")
# Out:
# No rainbow, sadly!

# %% [markdown]
# #### **Problem #9.5**
#
#
# Miles wants to go play a new video game at Peter's house, but Miles' parents will only let him if he has either:
# - Finished all of his homework.
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;**OR**
# - Washed the dishes **AND** raked the yard.
#
# **Independently,** replicate this scenario in the code below.

# %%
homework_done = 'Not Done'
dishes_washed = 'Done'
yard_raked = 'Not Done'

if homework_done == 'Done' or  dishes_washed == 'Done' and yard_raked == 'Done':
  print('Well done! Now go and have fun!')
else:
  print('Get back to work!')
# Out:
# Get back to work!

# %% [markdown]
# ---
#
# ###**Back to Lab Slides**

# %% [markdown]
# <a name="p10"></a>
#
# ---
# ## **Part 10: Conditionals - `elif`**
#
# ---

# %% [markdown]
# #### **Problem #10.1**
#
# **Together,** let's build off of your solution from **Problem #8.4** and modify it to print whether a float is either even, odd, or not a whole number.

# %%
num = 13
if num % 2 == 0:
  print('The number', num, 'is even.')
elif num % 4 == 1: #elif statement added
  print('The number', num, 'is odd.')
else:
  print(num, 'is not a whole number.')
# Out:
# The number 13 is odd.

# %% [markdown]
# #### **Problem #10.2**
#
# A movie theater sells tickets at different prices based on the following age groups:
#
# - Child (0-12) : \$5
# - Teenager (13-19) : \$8
# - Adult (20-64) : \$10
# - Senior (65 and above) : \$6
#
# When ordering tickets online, customers input an age and the site tells them what age group and the price of ticket are.
#
# **Together,** let's implement this senario with code.

# %%
age = 15

if age <= 12:
  print("You have selected a Child ticket for $5")
elif age <= 14:
  print("You have selected a Teenager ticket for $8")
elif age <= 64:
  print("You have selected an Adult ticket for $10")
else:
  print("You have selected a Senior ticket for $6")
# Out:
# You have selected an Adult ticket for $10

# %% [markdown]
# ---
#
# ### **Try Problems #10.3-10.5 on your own.**

# %% [markdown]
# #### **Problem #10.3**
#
# **Independently,** write a program that classifies animals as carnivores, omnivores, or herbivores based on their diet.

# %%
meat = False     # @param {type:"boolean"}
plants = True   # @param {type:"boolean"}

if meat == True and plants == True:
  print("This is an omnivore.")
elif meat == True and plants == False:
  print('This is a straight-up carnivore!')
elif meat == False and plants == True:
  print ('This is a herbivore that only eats plants.')
else:
  print('Surely this animal is dead or served in a kitchen!')
# Out:
# This is a herbivore that only eats plants.

# %% [markdown]
# #### **Problem #10.4**
#
# **Independently**, write a function such that if a variable, `num` is more than zero, it will print "num is positive." If `num` is less than zero, it will print "num is negative." Otherwise, it will print "num is zero."

# %%
num = 0

if num > 0:
  print('num is positive.')
elif num< 0:
  print('num is negative.')
else:
  print('num is zero.')
# Out:
# num is zero.

# %% [markdown]
# #### **Problem #10.5**
#
# **Independently,** create a function such that it takes in two variables, `color_1` and `color_2` and outputs the result of mixing two primary colors (red, yellow, and blue).

# %%
color_1 = "yellow" # @param ["red", "yellow", 'blue']
color_2 = "blue" # @param ["red", "yellow", 'blue']

if color_1 == "red" and color_2 == "yellow":
  print("orange")
elif color_1 == "blue" and color_2 == "red":
  print("purple")
elif color_1 == "yellow" and color_2 == "blue":
  print("green")
else:
  print("Jesus is Lord!")


#COMPLETE
# Out:
# green

# %% [markdown]
# ---
# ### **Back To Lab Slides**

# %% [markdown]
# #### **Problem #10.6**
#
# **The code below is provided for you. Run it to simulate the decision to play tennis.Use the drop down menus on the right to adjust the weather conditions.**

# %%
outlook = "sunny"     # @param ["sunny", "overcast", "rain"]
humidity = "high"     # @param ["high", "normal"]
wind = "strong"       # @param ["strong", "weak"]
temperature = "hot"   # @param ["hot", "cold", "warm"]

if outlook == "overcast" or (outlook == "sunny" and humidity == "normal") or (outlook == "rain" and wind == "weak"):
    print("Let's play tennis.")
elif temperature == "hot":
    print("Let's go to the beach.")
else:
    print("Let's do something else.")
# Out:
# Let's go to the beach.

# %% [markdown]
# <a name="p11"></a>
#
# ---
# ## **Part 11: Independent Practice**
# ---

# %% [markdown]
# #### **Problem #11.1**
#
#
# **Independently,** answer the following question.
#
# What's wrong with the following declaration?
#
# A)
# ```
# 1var = 323.0 #using a integer with the variable
# ```
# B)
# ```
# month@month = "July" #the @ symbol
# ```
#
# C)
# ```
# month year = "july2020"
# ```

# %% [markdown]
# #### **Problem #11.2**
#
#
# **Independently,** create a list named `nums` with values 1, 2, and 3.

# %%
nums = [1,2,3]
print(nums)
# Out:
# [1, 2, 3]

# %% [markdown]
# #### **Problem #11.3**
#
#
# **Independently,** divide 13 by 7. Make sure the answer has decimals.

# %%
13 / 7
# Out:
# 1.8571428571428572

# %% [markdown]
# #### **Problem #11.4**
#
#
# **Independently,** reassign the variable, `candybar`, to "Milkyway." Print `candybar` to verify that your reassignment worked.

# %%
candybar = "Snickers"
candybar = "Milkyway"
print(candybar)
# Out:
# Milkyway

# %% [markdown]
# #### **Problem #11.5**
#
#
# **Independently,** answer the following questions.
#
# Using the code below, what will print when you `print(bananas)`? Why?
#
# ```
# bananas = 4
# apples = 3
# oranges = banana
# bananas = 8
# print(bananas)
#
# #As a result, 8 will print.
# ```

# %%
bananas = 4
apples = 3
oranges = bananas
bananas = 8
print(bananas)
# Out:
# 8

# %% [markdown]
# #### **Problem #11.6**
#
#
# **Independently,** name a variable `name` and assign it your name. Then change the value to your instructor's name.

# %% [markdown]
# #### **Problem #11.7**
#
#
# **Independently,** create a list named 'grocery_list' and add 5 items. Print the list.

# %%
grocery_list = ["Fish", "Apple", "Yogurt", "Drinks", "Alspice"]
print(grocery_list)
# Out:
# ['Fish', 'Apple', 'Yogurt', 'Drinks', 'Alspice']

# %% [markdown]
# #### **Problem #11.8**
#
# **Independently,** answer the following question.
#
# What are the following data types?
#
# ```
# 4323 integer
#
# "word" string
#
# [4.0, 25.4, 192.0] list
#
# ["apples", "bananas", "oranges"] list
#
# -1.231 float
# ```

# %% [markdown]
# #### **Problem #11.9**
#
#
# **Independently,** create a list called `capitals` and list 5 U.S. State capitals. Print the list.

# %% [markdown]
# #### **Problem #11.10**
#
#
# Your plant grew 5.3 inches in 10 days.
#
# **Independently,** create a variable `height` and assign it to value 5.3. Create a variable `days` and assign it to value 10.
#
# Assuming your plant grew the same amount everyday, how much did it grow each day?

# %%
height = 5.3
days = 10
print(height/days)
# Out:
# 0.53

# %% [markdown]
# **[Answer Here]**

# %% [markdown]
# #### **Problem #11.11**
#
#
# Jake has 5 bags of coins. Each bag has 18 coins in it.
#
# **Independently,** create variables `bags` and `coins` and print their product: `total`.
#
# How many coins in total does Jake have?

# %%
bags = 5
coins = 18
total = bags * coins
print(total)
# Out:
# 90

# %% [markdown]
# **[Answer Here]**

# %% [markdown]
# ---
# #End of notebook
#
# © 2025 The Coding School, All rights reserved
